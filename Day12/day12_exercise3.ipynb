# %% [markdown]
# # Exercise Level3

# %% [markdown]
# ### 1. Call your function shuffle_list, it takes a list as a parameter and it returns a shuffled list
#
# ### 2. Write a function which returns an array of seven random numbers in a range of 0-9. All the numbers must be unique.

# %%
# 1

# shuffle_list
print('1.')
import random

def shuffle_list(lst):
    random.shuffle(lst) # .shuffle() shuffles the list in place
    return lst

my_list = [1, 2, 3, 4, 5]
print(f'Original list: {my_list}')
print(f'Shuffled list: {shuffle_list(my_list)}')
print()

# 2
print('2.')
def random_num():
    set1 = set()
    while len(set1) < 7:
        set1.add(random.randint(0, 9))
    return set1
    
x = list(random_num())
print(f'Random set of 7 unique numbers: {x}\n')
# Out:
# 1.
# Original list: [1, 2, 3, 4, 5]
# Shuffled list: [2, 1, 4, 3, 5]
#
# 2.
# Random set of 7 unique numbers: [0, 2, 3, 4, 7, 8, 9]

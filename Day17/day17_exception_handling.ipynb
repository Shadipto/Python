# %% [markdown]
# # Exception Handling

# %%
try:
    print(1 + '0')
except:
    print('Error: cannot add an integer and a string')
# Out:
# Error: cannot add an integer and a string

# %%
try:
    name = input('Enter your name:')
    year_born = input('Year you were born:') # did not convert to int
    age = 2026 - year_born
    print(f'You are {name}. And your age is {age}.')
except:
    print('Something went wrong')
# Out:
# Something went wrong

# %%
try:
    name = input('Enter your name:')
    year_born = input('Year you were born:') # did not convert to int, will cause TypeError when trying to subtract
    age = 2026 - year_born
    print(f'You are {name}. And your age is {age}.')
except TypeError:
    print('Type error occured')
except ValueError:
    print('Value error occured')
except ZeroDivisionError:
    print('zero division error occured')
# Out:
# Type error occured

# %%
try:
    name = input('Enter your name:')
    year_born = input('Year you born:')
    age = 2026 - int(year_born)
    print(f'You are {name}. And your age is {age}.')
except TypeError:
    print('Type error occur')
except ValueError:
    print('Value error occur')
except ZeroDivisionError:
    print('zero division error occur')
else:
    print('I usually run with the try block')
finally:
    print('I alway run.')
# Out:
# You are Shadipto. And your age is 24.
# I usually run with the try block
# I alway run.

# %%
try:
    name = input('Enter your name:')
    year_born = input('Year you born:') # did not convert to int, will cause TypeError when trying to subtract
    age = 2026 - (year_born) 
    print(f'You are {name}. And your age is {age}.')
except Exception as e:
    print(e)
# Out:
# unsupported operand type(s) for -: 'int' and 'str'

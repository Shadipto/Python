# %% [markdown]
# # Exercise

# %% [markdown]
# ### 1. Declare your age as integer variable
#
# ### 2. Declare your height as a float variable
#
# ### 3. Declare a variable that store a complex number
#
# ### 4. Write a script that prompts the user to enter base and height of the triangle and calculate an area of this triangle (area = 0.5 x b x h).
#
# ### 5. Write a script that prompts the user to enter side a, side b, and side c of the triangle. Calculate the perimeter of the triangle (perimeter = a + b + c).

# %%
# 1.

print('1.')
age = 22
print(f'Age: {age}')
print()

# 2.

print('2.')
height = 5.7
print(f'Height: {height}')
print()

# 3.

print('3.')
complex_num = 3 + 4j
print(f'Complex Number: {complex_num}')
print()

# 4.

print('4.')
base = float(input("Enter the base of the triangle: "))
height = float(input("Enter the height of the triangle: "))

print(f'Base: {base}')
print(f'Height: {height}')

print(f'Area of the triangle: {0.5 * base * height}') # area = 0.5 * base * height
print()
# Out:
# 1.
# Age: 22
#
# 2.
# Height: 5.7
#
# 3.
# Complex Number: (3+4j)
#
# 4.
# Base: 3.0
# Height: 3.0
# Area of the triangle: 4.5

# %%
# 5.

print('5.')
a = int(input("Enter the first number: "))
b = int(input("Enter the second number: "))
c = int(input("Enter the third number: "))

print(f'a = {a}, b = {b}, c = {c}')
print(f'Perimeter of the triangle: {a + b + c}') # perimeter = a + b + c
print()
# Out:
# 5.
# a = 1, b = 2, c = 3
# Perimeter of the triangle: 6

# %% [markdown]
# ### 6. Get length and width of a rectangle using prompt. Calculate its area (area = length x width) and perimeter (perimeter = 2 x (length + width))
#
# ### 7. Get radius of a circle using prompt. Calculate the area (area = pi x r x r) and circumference (c = 2 x pi x r) where pi = 3.14.
#
# ### 8. Calculate the slope, x-intercept and y-intercept of y = 2x -2
#
# ### 9. Slope is (m = y2-y1/x2-x1). Find the slope and Euclidean distance between point (2, 2) and point (6,10)
#
# ### 10. Compare the slopes in tasks 8 and 9.
#
# ### 11. Calculate the value of y (y = x^2 + 6x + 9). Try to use different x values and figure out at what x value y is going to be 0.
#
# ### 12. Find the length of 'python' and 'dragon' and make a falsy comparison statement.
#
# ### 13. Use and operator to check if 'on' is found in both 'python' and 'dragon'
#
# ### 14. I hope this course is not full of jargon. Use in operator to check if jargon is in the sentence.
#
# ### 15. There is no 'on' in both dragon and python
#
# ### 16. Find the length of the text python and convert the value to float and convert it to string
#
# ### 17. Even numbers are divisible by 2 and the remainder is zero. How do you check if a number is even or not using python?
#
# ### 18. Check if the floor division of 7 by 3 is equal to the int converted value of 2.7.
#
# ### 19. Check if type of '10' is equal to type of 10
#
# ### 20. Check if int('9.8') is equal to 10
#
# ### 21. Write a script that prompts the user to enter hours and rate per hour. Calculate pay of the person?
#
# ### 22. Write a script that prompts the user to enter number of years. Calculate the number of seconds a person can live. Assume a person can live hundred years
#
# ### 23. Write a Python script that displays the following table
# ###     1 1 1 1 1
# ###     2 1 2 4 8
# ###     3 1 3 9 27
# ###     4 1 4 16 64
# ###     5 1 5 25 125

# %%
# 6.

print('6.')
length = float(input("Enter the length of the rectangle: "))
width = float(input("Enter the width of the rectangle: "))

print(f'Length: {length}, Width: {width}')
print(f'Area of the rectangle: {length * width}') # area = length * width
print(f'Perimeter of the rectangle: {2 * (length + width)}') # perimeter = 2 * (length + width)
print()
# Out:
# 6.
# Length: 3.0, Width: 4.0
# Area of the rectangle: 12.0
# Perimeter of the rectangle: 14.0

# %%
# 7. 

print('7.')
radius = float(input("Enter the radius of the circle: "))
Pi = 3.1416

print(f'Radius: {radius}')
print(f'Area of the circle: {Pi * radius ** 2}') # area = pi * radius^2
print(f'Circumference of the circle: {2 * Pi * radius}') # circumference = 2 * pi * radius
print()
# Out:
# 7.
# Radius: 5.0
# Area of the circle: 78.53999999999999
# Circumference of the circle: 31.416

# %%
# 8.

print('8.')
# equation: y = 2x - 2
print("Equation: y = 2x - 2")

m = 2 # slope
c = -2 # constant term

intercept_y = (0,(2 * 0) - 2) # x = 0 at y-intercept
intercept_x = (2/2,0) # y = 0 at x-intercept

print(f'x-intercept: {intercept_x}')
print(f'y-intercept: {intercept_y}')
print()


# 9.

import math

# (2,2) and (6,10)

print('9.')
print("Points: (2,2) and (6,10)")

x1, y1 = 2, 2
x2, y2 = 6, 10

# slope = (y2 - y1) / (x2 - x1)
slope = (y2 - y1) / (x2 - x1) 

# euclidean distance = sqrt((x2 - x1)^2 + (y2 - y1)^2)
distance = math.sqrt(math.pow((x2-x1), 2) + math.pow((y2-y1), 2))

print(f'Slope: {slope}')
print(f'Euclidean Distance: {distance}')
print()


# 10.

print('10.')
if(m > slope):
    print("The slope of task-8 is greater than task-9.")
elif(m < slope):
    print("The slope of task-9 is greater than task-8.")
else:
    print("The slopes of task-8 and task-9 are equal.")

print()
# Out:
# 8.
# Equation: y = 2x - 2
# x-intercept: (1.0, 0)
# y-intercept: (0, -2)
#
# 9.
# Points: (2,2) and (6,10)
# Slope: 2.0
# Euclidean Distance: 8.94427190999916
#
# 10.
# The slopes of task-8 and task-9 are equal.

# %%
# 11.

# (y = x^2 + 6x + 9)
print('11.')

for x in range(-10, 11):
    y = x ** 2 + 6 * x + 9 
    if (y == 0):
        print(f'Y = 0, when x = {x}')
        break
print()

# 12.

print('12.')
print(f'Falsy comparisons of "dragon" and "python": {len("dragon") != len("python")}') # output False
print()

# 13.

print('13.')
print(f'Finding "on" in "dragon" and "python": {"on" in "dragon" and "on" in "python"}') 
print()

# 14.

print('14.')
print(f'Checking if "jargon" is in sentence: {"jargon" in "I hope this course is not full of jargon."}') 
print()

# 15.

print('15.')
print(f'Not finding "on" in "dragon" and "python": {"on" not in "dragon" and "on" not in "python"}')
print()

# 16.

print('16.')

a = len('python')
print(f'Length of "python": {a}')

print(f'Type of "a": {type(a)}')

a = float(a)
print(f'Type of "a" int to float: {type(a)}')
a = str(a)
print(f'Type of "a" float to string: {type(a)}')
print()
# Out:
# 11.
# Y = 0, when x = -3
#
# 12.
# Falsy comparisons of "dragon" and "python": False
#
# 13.
# Finding "on" in "dragon" and "python": True
#
# 14.
# Checking if "jargon" is in sentence: True
#
# 15.
# Not finding "on" in "dragon" and "python": False
#
# 16.
# Length of "python": 6
# Type of "a": <class 'int'>
# Type of "a" int to float: <class 'float'>
# Type of "a" float to string: <class 'str'>

# %%
# 17.

print('17.')
a = int(input("Enter a number: "))
print(f'Input number: {a}')

if (a % 2 == 0):
    print(f'{a} is an even number.')
else:
    print(f'{a} is an odd number.')
print()
# Out:
# 17.
# Input number: 5
# 5 is an odd number.

# %%
# 18.

print('18.')

print(f'Checking if (7 // 3) is equal to 2.7 converted to int: {(7 // 3) == int(2.7)}')
print()

# 19.

print('19.')
print(f'Checking if "10" is equal to 10: {"10" == 10}')
print()

# 20.

print('20.')

print(f'Checking if "9.8" converted to int is equal to 10: {int(float("9.8")) == 10}') # must do str to float and then float to int, otherwise it will throw an error [cant do int("9.8")]
print()
# Out:
# 18.
# Checking if (7 // 3) is equal to 2.7 converted to int: True
#
# 19.
# Checking if "10" is equal to 10: False
#
# 20.
# Checking if "9.8" converted to int is equal to 10: False

# %%
# 21.

print('21.')

hours = int(input("Enter hours: "))
rate = float(input("Enter rate per hour: "))

print(f'Hours: {hours}, Rate per hour: {rate}')
print(f'Weekly pay: {hours * rate}')
print()
# Out:
# 21.
# Hours: 40, Rate per hour: 28.0
# Weekly pay: 1120.0

# %%
# 22.

print('22.')

years = int(input('Enter num of years u have lived: '))

print(f'Num of years lived: {years}')
print(f'You lived for {years * 365 * 24 * 60 * 60} seconds') # converting years to seconds
print()
# Out:
# 22.
# Num of years lived: 100
# You lived for 3153600000 seconds

# %%
# 23.

# Write a Python script that displays the following table
# 1 1 1 1 1
# 2 1 2 4 8
# 3 1 3 9 27
# 4 1 4 16 64
# 5 1 5 25 125

import math

print('23.')

for i in range(1, 6):
    print(f'{i} {1} {i} {int(math.pow(i, 2))} {int(math.pow(i, 3))}')

print()
# Out:
# 23.
# 1 1 1 1 1
# 2 1 2 4 8
# 3 1 3 9 27
# 4 1 4 16 64
# 5 1 5 25 125

# %% [markdown]
# # Exercise Level2

# %% [markdown]
# ### 1. Use for loop to iterate from 0 to 100 and print the sum of all numbers.
#
# ### 2. Use for loop to iterate from 0 to 100 and print the sum of all evens and the sum of all odds.

# %%
# 1.

print('1.')
print(f'Printing the sum from 0 to 100 using for loop\n')
total = 0
for i in range(101):
    total += i
print(f'The sum from 0 to 100 is: {total}\n')

# 2.
print('2.')
print(f'Printing the sum of all even and odd from 0 to 100 using loops\n')
even_sum = 0
odd_sum = 0
for i in range(101):
    if i % 2 == 0:
        even_sum += i
    else:
        odd_sum += i
print(f'The sum of all even numbers from 0 to 100 is: {even_sum}')
print(f'The sum of all odd numbers from 0 to 100 is: {odd_sum}\n')
# Out:
# 1.
# Printing the sum from 0 to 100 using for loop
#
# The sum from 0 to 100 is: 5050
#
# 2.
# Printing the sum of all even and odd from 0 to 100 using loops
#
# The sum of all even numbers from 0 to 100 is: 2550
# The sum of all odd numbers from 0 to 100 is: 2500

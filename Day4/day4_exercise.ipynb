# %% [markdown]
# # Exercise

# %% [markdown]
# ### 1. Concatenate the string 'Thirty', 'Days', 'Of', 'Python' to a single string, 'Thirty Days Of Python'.
#
# ### 2. Concatenate the string 'Coding', 'For' , 'All' to a single string, 'Coding For All'.
#
# ### 3. Declare a variable named company and assign it to an initial value "Coding For All".
#
# ### 4. Print the variable company using print().
#
# ### 5. Print the length of the company string using len() method and print().
#
# ### 6. Change all the characters to uppercase letters using upper() method.
#
# ### 7. Change all the characters to lowercase letters using lower() method.
#
# ### 8. Use capitalize(), title(), swapcase() methods to format the value of the string Coding For All.
#
# ### 9. Cut(slice) out the first word of Coding For All string.
#
# ### 10. Check if Coding For All string contains a word Coding using the method index, find or other methods.

# %%
# 1.

print('1.')
a,b,c,d = 'Thirty', 'Days', 'Of', 'Python'

print(a)
print(b)
print(c)
print(d)
print(f'Concatinated string: {a} {b} {c} {d}')
print()

# 2.

print('2.')
a,b,c,d = 'Coding', 'For', 'All', 'Python'

print(a)
print(b)
print(c)
print(d)
print(f'Concatinated string: {a} {b} {c} {d}')
print()

# 3.

print('3.')
company = 'Coding For All'

# 4.

print('4.')
print(f'Printing the variable company: {company}')
print()

# 5.

print('5.')
print(f'Length of the string company: {len(company)}')
print()

# 6.

print('6.')
print(f'Changing all characters in company to uppercase: {company.upper()}')
print()

# 7.

print('7.')
print(f'Changing all characters in company to lowercase: {company.lower()}')
print()

# 8.

print('8.')
print(f'Capitalizing the first letter of company: {company.capitalize()}')
print()
print(f'Title case of company: {company.title()}')
print()
print(f'Swapping the case of company: {company.swapcase()}')
print()

# 9.

print('9.')
print(f'Slicing out the first word of the company string: {company[6:]}')
print()

# 10.

print('10.')

try:
    print(f'Checking if hte company string contains the word "Coding": {company.index("Coding")}')
except ValueError:
    print('The word "Coding" is not found in the company string.')
print()
# Out:
# 1.
# Thirty
# Days
# Of
# Python
# Concatinated string: Thirty Days Of Python
#
# 2.
# Coding
# For
# All
# Python
# Concatinated string: Coding For All Python
#
# 3.
# 4.
# Printing the variable company: Coding For All
#
# 5.
# Length of the string company: 14
#
# 6.
# Changing all characters in company to uppercase: CODING FOR ALL
#
# 7.
# Changing all characters in company to lowercase: coding for all
#
# 8.
# Capitalizing the first letter of company: Coding for all
#
# Title case of company: Coding For All
#
# Swapping the case of company: cODING fOR aLL
#
# 9.
# Slicing out the first word of the company string:  For All
#
# 10.
# Checking if hte company string contains the word "Coding": 0

# %% [markdown]
# ### 11. Replace the word coding in the string 'Coding For All' to Python.
#
# ### 12. Change "Python for Everyone" to "Python for All" using the replace method or other methods.
#
# ### 13. Split the string 'Coding For All' using space as the separator (split()).
#
# ### 14. "Facebook, Google, Microsoft, Apple, IBM, Oracle, Amazon" split the string at the comma.
#
# ### 15. What is the character at index 0 in the string Coding For All.
#
# ### 16. What is the last index of the string Coding For All.
#
# ### 17. What character is at index 10 in "Coding For All" string.
#
# ### 18. Create an acronym or an abbreviation for the name 'Python For Everyone'.
#
# ### 19. Create an acronym or an abbreviation for the name 'Coding For All'.
#
# ### 20. Use index to determine the position of the first occurrence of C in Coding For All.

# %%
# 11.

company = 'Coding For All'

print('11.')
print(f'Replacing the word "Coding" with "Python" in the string company: {company.replace('Coding', 'Python')}')
print()

# 12.

txt = 'Python For Everyone'
print('12.')
print(f'txt: {txt}')
print(f'Replacing the word "Python For Everyone" to "Python For All" in the string company: {company.replace('Everyone','All')}')
print()

# 13.

print('13.')
print(f'Splitting the company string using space(" ") as the seperator: {company.split(" ")}')
print()

# 14.

print('14.')
social = "Facebook, Google, Microsoft, Apple, IBM, Oracle, Amazon"
print(f'social: {social}')
print(f'Splitting the social string using coma(,) as the seperator: {social.split(",")}')
print()

# 15.

print('15.')
company = 'Coding For All'
print(f'Company: {company}')
print(f'Character at index 0: {company[0]}')
print()

# 16.

print('16.')
print(f'company: {company}')
print(f'Character at index last index: {company[len(company)-1]}')
print()

# 17.

print('17.')
print(f'company: {company}')
print(f'Character at index 10: {company[10]}')
print()

# 18.

print('18.')
test = 'Python For Everyone'
print(f'test: {test}')
print(f'Acronym of {test}: {".".join([test[0] for test in test.split()])}')
print()

# 19.

print('19.')
test2 = 'Coding For All'
print(f'test2 = {test2}')
print(f'Acronym of {test2}: {".".join([test2[0] for test2 in test2.split()])}')
print()

# 20.

print('20.')
string = 'Coding For All'
print(f'string: {string}')
print(f'Index of 1st "C" in {string}: {string.index('C')}')
print()
# Out:
# 11.
# Replacing the word "Coding" with "Python" in the string company: Python For All
#
# 12.
# txt: Python For Everyone
# Replacing the word "Python For Everyone" to "Python For All" in the string company: Coding For All
#
# 13.
# Splitting the company string using space(" ") as the seperator: ['Coding', 'For', 'All']
#
# 14.
# social: Facebook, Google, Microsoft, Apple, IBM, Oracle, Amazon
# Splitting the social string using coma(,) as the seperator: ['Facebook', ' Google', ' Microsoft', ' Apple', ' IBM', ' Oracle', ' Amazon']
#
# 15.
# Company: Coding For All
# Character at index 0: C
#
# 16.
# company: Coding For All
# Character at index last index: l
#
# 17.
# company: Coding For All
# Character at index 10:
#
# 18.
# test: Python For Everyone
# Acronym of Python For Everyone: P.F.E
#
# 19.
# test2 = Coding For All
# Acronym of Coding For All: C.F.A
#
# 20.
# string: Coding For All
# Index of 1st "C" in Coding For All: 0

# %% [markdown]
# ### 21. Use index to determine the position of the first occurrence of F in Coding For All.
#
# ### 22. Use rfind to determine the position of the last occurrence of l in Coding For All People.
#
# ### 23. Use index or find to find the position of the first occurrence of the word 'because' in the following sentence: 'You cannot end a sentence with because because because is a conjunction'
#
# ### 24. Use rindex to find the position of the last occurrence of the word because in the following sentence: 'You cannot end a sentence with because because because is a conjunction'
#
# ### 25. Slice out the phrase 'because because because' in the following sentence: 'You cannot end a sentence with because because because is a conjunction'

# %%
# 21.

print('21.')
string = 'Coding For All'
print(f'string: {string}')
print(f'Index of 1st occurance of "F" in {string}: {string.index('F')}')
print()

# 22.

print('22.')
print(f'Index of last occurance of "l" in {string}: {string.rindex('l')}')
print()

# 23.

print('23.')
sentence = 'You cannot end a sentence with because because because is a conjunction'
print(f'sentence: {sentence}')
print(f'Index of 1st occurance of "because" in sentence: {sentence.index('because')}')
print()

# 24.

print('24.')
print(f'Index of last occurance of "because" in sentence: {sentence.rindex('because')}')
print()

# 25.
print('25.')
print(f'Slicing out the phrase "because because because" from the sentence: \n{sentence.replace('because because because', '')}')
print()
# Out:
# 21.
# string: Coding For All
# Index of 1st occurance of "F" in Coding For All: 7
#
# 22.
# Index of last occurance of "l" in Coding For All: 13
#
# 23.
# sentence: You cannot end a sentence with because because because is a conjunction
# Index of 1st occurance of "because" in sentence: 31
#
# 24.
# Index of last occurance of "because" in sentence: 47
#
# 25.
# Slicing out the phrase "because because because" from the sentence:
# You cannot end a sentence with  is a conjunction

# %% [markdown]
# ### 26. Find the position of the first occurrence of the word 'because' in the following sentence: 'You cannot end a sentence with because because because is a conjunction'
#
# ### 27. Slice out the phrase 'because because because' in the following sentence: 'You cannot end a sentence with because because because is a conjunction'
#
# ### 28. Does 'Coding For All' start with a substring Coding?
#
# ### 29. Does 'Coding For All' end with a substring coding?
#
# ### 30. "   Coding For All      "  , remove the left and right trailing spaces in the given string.
#
# ### 31. Which one of the following variables return True when we use the method isidentifier():
#    * 30DaysOfPython
#    * thirty_days_of_python
#
# ### 32. The following list contains the names of some of python libraries: ['Django', 'Flask', 'Bottle', 'Pyramid', 'Falcon']. Join the list with a hash with space string.
#
# ### 33. Use the new line escape sequence to separate the following sentences.
#    * I am enjoying this challenge.
#    * I just wonder what is next.

# %%
# 26.

print('26.')
sentence = 'You cannot end a sentence with because because because is a conjunction'
print(f'sentence: {sentence}')
print(f'Finding the 1st position of "because" in the sentence: {sentence.index('because')}')
print()

# 27.

print('27.')
print(f'Removing the phrase "because because because" from the sentence: \n{sentence.replace('because because because', '')}')
print()

# 28.

print('28.')
company = 'Coding For All'
print(f'company: {company}')
print(f'Does {company} start with "Coding"? {company.startswith('Coding')}')
print()

# 29.

print('29.')
print(f'Does {company} end with "Coding"? {company.endswith('Coding')}')
print()

# 30.

print('30.')
abar = '   Coding For All      '
print(f'abar: "{abar}"')
print(f'abar after stripping the leading and trailing spaces: "{abar.strip()}"')
print()

# 31.

print('31.')
print(f'30DaysOfPython isidentifier: {"30DaysOfPython".isidentifier()}')
print(f'Thirty_Days_Of_Python isidentifier: {"ThirtyDaysOfPython".isidentifier()}')
print()

# 32.

print('32.')
list = ['Django', 'Flask', 'Bottle', 'Pyramid', 'Falcon']
print(f'list: {list}')
print(f'Joining the list with a "# " separator: {"# ".join(list)}')
print()

# 33.

print('33.')
print('I am enjoying this challange. \nI just wonder what is next.')
print()
# Out:
# 26.
# sentence: You cannot end a sentence with because because because is a conjunction
# Finding the 1st position of "because" in the sentence: 31
#
# 27.
# Removing the phrase "because because because" from the sentence:
# You cannot end a sentence with  is a conjunction
#
# 28.
# company: Coding For All
# Does Coding For All start with "Coding"? True
#
# 29.
# Does Coding For All end with "Coding"? False
#
# 30.
# abar: "   Coding For All      "
# abar after stripping the leading and trailing spaces: "Coding For All"
#
# 31.
# 30DaysOfPython isidentifier: False
# Thirty_Days_Of_Python isidentifier: True
#
# 32.
# list: ['Django', 'Flask', 'Bottle', 'Pyramid', 'Falcon']
# Joining the list with a "# " separator: Django# Flask# Bottle# Pyramid# Falcon
#
# 33.
# I am enjoying this challange.
# I just wonder what is next.
